# %% [markdown]
# ## IQR (Interquartile Range)

# %% [markdown]
# It's the data Range that contains the middle 50% of the entries.
# IQR = Q3 -Q1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("scholarship.csv")

# %%
data.head()
# Out:
#    semester_percentage  scholarship_exam_marks  got_scholarship
# 0                 71.9                      26                1
# 1                 74.6                      38                1
# 2                 75.4                      40                1
# 3                 64.2                       8                1
# 4                 72.3                      17                0

# %%
sns.displot(data["scholarship_exam_marks"])
# Out:
# C:\Users\advai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(data["scholarship_exam_marks"])
# Out:
# C:\Users\advai\AppData\Local\Temp\ipykernel_8536\828206924.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# C:\Users\advai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='scholarship_exam_marks', ylabel='Density'>

# %%
sns.boxplot(data["scholarship_exam_marks"])
# Out:
# <Axes: >

# %%
Q1 = data["scholarship_exam_marks"].quantile(0.25)
Q3 = data["scholarship_exam_marks"].quantile(0.75)

# %%
Q1
# Out:
# 17.0

# %%
Q3
# Out:
# 44.0

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# 27.0

# %%
data.describe()
# Out:
#        semester_percentage  scholarship_exam_marks  got_scholarship
# count          1000.000000             1000.000000      1000.000000
# mean             69.612400               32.225000         0.489000
# std               6.158979               19.130822         0.500129
# min              48.900000                0.000000         0.000000
# 25%              65.500000               17.000000         0.000000
# 50%              69.600000               28.000000         0.000000
# 75%              73.700000               44.000000         1.000000
# max              91.200000              100.000000         1.000000

# %%
min = Q1 - 1.5 * IQR
max = Q3 + 1.5 * IQR

# %%
min
# Out:
# -23.5

# %%
max
# Out:
# 84.5

# %%
data[(data["scholarship_exam_marks"]<min) | (data["scholarship_exam_marks"]>max)]
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 9                   77.5                      94                1
# 40                  66.0                      86                1
# 61                  75.1                      86                0
# 134                 63.3                      93                0
# 162                 78.0                      90                0
# 283                 70.9                      87                0
# 290                 83.8                      87                0
# 311                 69.7                      87                1
# 324                 66.4                      90                0
# 630                 65.6                      96                1
# 685                 60.5                      87                1
# 730                 61.4                      90                1
# 771                 73.1                      86                1
# 846                 69.9                      97                0
# 917                 59.5                     100                0

# %% [markdown]
# # Trimming

# %%
new_data = data[(data["scholarship_exam_marks"]<min) & (data["scholarship_exam_marks"]>max)]

# %%
plt.figure(figsize = (16,8))
plt.subplot(2,2,1)
sns.distplot(data["scholarship_exam_marks"])

plt.subplot(2,2,2)
sns.boxplot(data["scholarship_exam_marks"])

plt.show()
# Out:
# C:\Users\advai\AppData\Local\Temp\ipykernel_8536\974372153.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["scholarship_exam_marks"])
# C:\Users\advai\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Capping

# %%
data["scholarship_exam_marks"] = np.where(data["scholarship_exam_marks"] > max, max, 
                                         np.where(data["scholarship_exam_marks"]<min, min, data["scholarship_exam_marks"]))

# %%
data.shape
# Out:
# (1000, 3)

# %%
sns.boxplot(data["scholarship_exam_marks"])
# Out:
# <Axes: >
